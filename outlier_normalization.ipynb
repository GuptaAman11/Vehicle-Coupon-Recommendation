# %%
df_clone = df
#exp3
import seaborn as sns
import matplotlib.pyplot as plt

# Set the size of the plot
plt.figure(figsize=(12, 6))

# Assuming 'df2' is your DataFrame
sns.boxplot(data=df_clone)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.show()

# %%
print(plt.figure(figsize = (10, 4), dpi = 100)) 
sns.boxplot(x = "temperature", data = df)
# Out:
# Figure(1000x400)
# <Axes: xlabel='temperature'>

# %%
percentile25 = df['temperature'].quantile(0.25)
percentile75 = df['temperature'].quantile(0.75)
iqr = percentile75 - percentile25
iqr
# Out:
# 25.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 117.5
# 17.5

# %%
df[df['temperature'] > upper_limit]
df[df['temperature'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [destination, passanger, weather, temperature, time, coupon, expiration, gender, age, maritalStatus, has_children, education, occupation, income, car, Bar, CoffeeHouse, CarryAway, RestaurantLessThan20, Restaurant20To50, toCoupon_GEQ5min, toCoupon_GEQ15min, toCoupon_GEQ25min, direction_same, direction_opp, Y]
# Index: []
#
# [0 rows x 26 columns]

# %%
print("Highest allowed",df['temperature'].mean() + 3*df['temperature'].std())
print("Lowest allowed",df['temperature'].mean() - 3*df['temperature'].std())
# Out:
# Highest allowed 125.44088733349552
# Lowest allowed 2.4935182168040626

# %%
df[(df['temperature'] > 125.44) | (df['temperature'] < 2.49)]
# Out:
#          destination  passanger weather  temperature  time  \
# 3    No Urgent Place  Friend(s)   Sunny          140   2PM
# 4    No Urgent Place  Friend(s)   Sunny          140   2PM
# 5    No Urgent Place  Friend(s)   Sunny          140   6PM
# 6    No Urgent Place  Friend(s)   Sunny          140   2PM
# 7    No Urgent Place     Kid(s)   Sunny          140  10AM
# ..               ...        ...     ...          ...   ...
# 117  No Urgent Place  Friend(s)   Sunny          140   2PM
# 118  No Urgent Place  Friend(s)   Sunny          140   6PM
# 119  No Urgent Place  Friend(s)   Sunny          140   6PM
# 120  No Urgent Place  Friend(s)   Sunny          140   2PM
# 121  No Urgent Place  Friend(s)   Sunny          140   2PM
#
#                     coupon expiration  gender age      maritalStatus  ...  \
# 3             Coffee House         2h  Female  21  Unmarried partner  ...
# 4             Coffee House         1d  Female  21  Unmarried partner  ...
# ...

# %%
new_df1 = df[(df['temperature'] < 122.05) & (df['temperature'] > 3.57)]
new_df1
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 122    No Urgent Place      Alone   Sunny           55  10AM
# 123               Home      Alone   Sunny           55   6PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# ...

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['temperature'])
plt.subplot(2,2,2)
sns.boxplot(df['temperature'])
plt.subplot(2,2,3)
sns.distplot(new_df1['temperature'])
plt.subplot(2,2,4)
sns.boxplot(new_df1['temperature'])
plt.show()

# %%
#exp 4
# %matplotlib inline

import sys
import scipy
import scipy.stats as ss
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
df = pd.read_csv("/Users/shubham/Downloads/vehicle.csv")

# %%
print(df1.shape)
df1.head()
# Out:
# (12684, 26)
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny          140   2PM
# 4  No Urgent Place  Friend(s)   Sunny          140   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %%
df = df.drop(columns=['car', 'toCoupon_GEQ5min', 'direction_opp'])

# %%
df = df.fillna(df.mode().iloc[0])

# %%
df.duplicated().sum()
# Out:
# 74

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = pd.read_csv("/Users/shubham/Downloads/vehicle.csv") 
print(df.shape)
df.head(8)
# Out:
# (12684, 26)
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny          140   2PM
# 4  No Urgent Place  Friend(s)   Sunny          140   2PM
# 5  No Urgent Place  Friend(s)   Sunny          140   6PM
# 6  No Urgent Place  Friend(s)   Sunny          140   2PM
# 7  No Urgent Place     Kid(s)   Sunny          140  10AM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
# ...

# %%
mean_rate = df['temperature'].mean()
stdev_rate = df['temperature'].std(ddof=0)

# %%
print('Mean participation rate is {:.3f}'.format(mean_rate))
print('Standard deviation is {:.3f}'.format(stdev_rate))
# Out:
# Mean participation rate is 63.967
# Standard deviation is 20.490

# %%
zscore_rate = ss.zscore(df['temperature'], ddof=0)
df = df.assign(zscore=zscore_rate)
print(df[['temperature', 'age', 'zscore']].iloc[:7])
# Out:
#    temperature age    zscore
# 0           55  21 -0.437629
# 1           80  21  0.782453
# 2           80  21  0.782453
# 3          140  21  3.710651
# 4          140  21  3.710651
# 5          140  21  3.710651
# 6          140  21  3.710651

# %%
threshold = 2
score_data = df['zscore'].copy().sort_values(ascending=False).values
ranks = np.linspace(1, len(score_data), len(score_data))
mask_outlier = (score_data < threshold)

plt.figure(dpi=150)
plt.plot(ranks[~mask_outlier], score_data[~mask_outlier], 'o', color='r', label='anomalies')
plt.plot(ranks[mask_outlier], score_data[mask_outlier], 'o', color='b', label='temperature')
plt.axhline(threshold, color='r', label='threshold', alpha=0.5)
plt.legend(loc='lower left')
plt.title('Z-score vs. temperature', fontweight='bold')
plt.xlabel('Rank')
plt.ylabel('Z-score')
plt.show()

# %%
zscore_anomalies = df[(df['zscore'] > 2)]
zscore_anomalies
# Out:
#          destination  passanger weather  temperature  time  \
# 3    No Urgent Place  Friend(s)   Sunny          140   2PM
# 4    No Urgent Place  Friend(s)   Sunny          140   2PM
# 5    No Urgent Place  Friend(s)   Sunny          140   6PM
# 6    No Urgent Place  Friend(s)   Sunny          140   2PM
# 7    No Urgent Place     Kid(s)   Sunny          140  10AM
# 8    No Urgent Place     Kid(s)   Sunny          140  10AM
# 9    No Urgent Place     Kid(s)   Sunny          140  10AM
# 10   No Urgent Place     Kid(s)   Sunny          140   2PM
# 11   No Urgent Place     Kid(s)   Sunny          140   2PM
# 12   No Urgent Place     Kid(s)   Sunny          140   6PM
# 13              Home      Alone   Sunny          140   6PM
# 14              Home      Alone   Sunny          140   6PM
# 15              Home      Alone   Sunny          140   6PM
# 16              Work      Alone   Sunny          140   7AM
# 17              Work      Alone   Sunny          140   7AM
# ...

# %%
nbins= 20
n_hist, bins_hist, patches_hist = plt.hist(ct_test['temperature'], nbins, density=False,
                           cumulative=False, linewidth=1.0, label='data')

# %%
from scipy.stats import skew, kurtosis

# Assuming data is your dataset
data = df['temperature']

# Calculate skewness and kurtosis
skewness = skew(data)
kurt = kurtosis(data)

print(f"Skewness: {skewness}")
print(f"Kurtosis: {kurt}")
# Out:
# Skewness: -0.1275824030241948
# Kurtosis: 0.3651275310975346

# %%
import random
import matplotlib.pyplot as plt

num_bins = 130
mean_rate = df['temperature'].mean()
stdev_rate = df['temperature'].std()

# Generate a normal distribution
normal_dist = [random.gauss(mean_rate, stdev_rate) for _ in range(500)]

# Plot the empirical CDF of the 'temperature' data
n, bins, patches = plt.hist(df['temperature'], num_bins, density=True, histtype='step',
                             cumulative=True, linewidth=1.0, label='data')

# Plot the CDF of the normal distribution
sorted_normal_dist = sorted(normal_dist)
plt.plot(sorted_normal_dist, [i/len(sorted_normal_dist) for i in range(len(sorted_normal_dist))],
         label='normal distribution')

plt.grid(True)
plt.legend(loc='upper left')
plt.xlabel('temperature')
plt.ylabel('Cumulative probability')
plt.show()

# %%
def modified_zscore(data, consistency_correction=1.4826):
    """
    Returns the modified z score and Median Absolute Deviation (MAD) from the scores in data.
    The consistency_correction factor converts the MAD to the standard deviation for a given
    distribution. The default value (1.4826) is the conversion factor if the underlying data
    is normally distributed
    """
    median = np.median(data)
    
    deviation_from_med = np.array(data) - median

    mad = np.median(np.abs(deviation_from_med))
    mod_zscore = deviation_from_med/(consistency_correction*mad)
    return mod_zscore, mad

# %%
mad_zscore, mad_participation = modified_zscore(df['temperature'])
z_sc_participation = df.assign(zscore_median=mad_zscore)
# Out:
# /var/folders/sv/wb5xf6jj7jg56c9qfm6rybtc0000gn/T/ipykernel_1177/986558247.py:13: RuntimeWarning: divide by zero encountered in divide
#   mod_zscore = deviation_from_med/(consistency_correction*mad)
# /var/folders/sv/wb5xf6jj7jg56c9qfm6rybtc0000gn/T/ipykernel_1177/986558247.py:13: RuntimeWarning: invalid value encountered in divide
#   mod_zscore = deviation_from_med/(consistency_correction*mad)

# %%
mod_zscore_anomalies = z_sc_participation[(z_sc_participation['zscore_median'] > 2)]
mod_zscore_anomalies
# Out:
#          destination  passanger weather  temperature  time  \
# 3    No Urgent Place  Friend(s)   Sunny          140   2PM
# 4    No Urgent Place  Friend(s)   Sunny          140   2PM
# 5    No Urgent Place  Friend(s)   Sunny          140   6PM
# 6    No Urgent Place  Friend(s)   Sunny          140   2PM
# 7    No Urgent Place     Kid(s)   Sunny          140  10AM
# 8    No Urgent Place     Kid(s)   Sunny          140  10AM
# 9    No Urgent Place     Kid(s)   Sunny          140  10AM
# 10   No Urgent Place     Kid(s)   Sunny          140   2PM
# 11   No Urgent Place     Kid(s)   Sunny          140   2PM
# 12   No Urgent Place     Kid(s)   Sunny          140   6PM
# 13              Home      Alone   Sunny          140   6PM
# 14              Home      Alone   Sunny          140   6PM
# 15              Home      Alone   Sunny          140   6PM
# 16              Work      Alone   Sunny          140   7AM
# 17              Work      Alone   Sunny          140   7AM
# ...

# %%
z_sc_participation['zscore_median'].describe()
# Out:
# /Users/shubham/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# count    6202.0
# mean        NaN
# std         NaN
# min        -inf
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         inf
# Name: zscore_median, dtype: float64

# %%
z_sc_participation['zscore'].describe()
# Out:
# count    1.261000e+04
# mean    -3.606244e-17
# std      1.000040e+00
# min     -1.655600e+00
# 25%     -4.359714e-01
# 50%      7.836574e-01
# 75%      7.836574e-01
# max      3.710767e+00
# Name: zscore, dtype: float64
